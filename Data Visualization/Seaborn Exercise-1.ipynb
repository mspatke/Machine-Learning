# %%
import pandas as pd

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
df= pd.read_excel("D:\Python\Seaborn\car_data.xlsx",sheet_name='cars_bangalore')

# %%
df.head()
# Out:
#   Brand Model  Year Fuel Type  Kilometer    Price       City
# 0  Audi    A3  2018    Petrol       6703  2640000     Mumbai
# 1  Audi    A3  2015    Diesel      83418  1680000    Gurgaon
# 2  Audi    A3  2015    Diesel      43181  1850000    Gurgaon
# 3  Audi    A4  2014    Diesel      66935  1700000  Ahmedabad
# 4  Audi    A4  2013    Diesel      58898  1440000  Ahmedabad

# %%
df.describe()
# Out:
#               Year     Kilometer         Price
# count  6077.000000  6.077000e+03  6.077000e+03
# mean   2011.733257  7.654177e+04  3.885345e+05
# std       3.750151  5.459185e+04  3.709437e+05
# min    1995.000000  1.000000e+00  1.500000e+04
# 25%    2010.000000  4.321600e+04  1.500000e+05
# 50%    2012.000000  7.223200e+04  3.000000e+05
# 75%    2015.000000  9.928300e+04  5.000000e+05
# max    2019.000000  2.000822e+06  5.500000e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6077 entries, 0 to 6076
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Brand      6077 non-null   object
#  1   Model      6077 non-null   object
#  2   Year       6077 non-null   int64
#  3   Fuel Type  6077 non-null   object
#  4   Kilometer  6077 non-null   int64
#  5   Price      6077 non-null   int64
#  6   City       6077 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 332.5+ KB

# %%
df.sample()
# Out:
#      Brand   Model  Year Fuel Type  Kilometer  Price    City
# 5230  Tata  Indigo  2005    Petrol      47405  30000  Mumbai

# %%
sns.relplot('Fuel Type','Year',data=df)

# %%
sns.relplot('Year','Price',data=df,hue='Brand')

# %%
sns.relplot('Year','Price',data=df,hue='Model')

# %%
sns.relplot('Year','Price',data=df,hue='Fuel Type',style='Fuel Type')

# %%
sns.relplot('Year','Price',data=df,size='Kilometer',sizes=(10,200))

# %%
df.head(3)
# Out:
#   Brand Model  Year Fuel Type  Kilometer    Price     City
# 0  Audi    A3  2018    Petrol       6703  2640000   Mumbai
# 1  Audi    A3  2015    Diesel      83418  1680000  Gurgaon
# 2  Audi    A3  2015    Diesel      43181  1850000  Gurgaon

# %%
sns.relplot('Kilometer','Price',data=df,kind='line')

# %%
sns.relplot('Kilometer','Price',data=df,kind='line',hue="Fuel Type")

# %%
sns.relplot('Kilometer','Price',data=df,kind='line',hue="Brand")

# %%
sns.relplot('Kilometer','Price',data=df, kind='line', hue='City',marker='o',dashes=True)

# %%
sns.relplot('Kilometer','Price',data=df, kind='line', hue='City',col='City')

# %%
sns.relplot('Kilometer','Price',data=df, kind='line',hue='City' ,col='Fuel Type',col_wrap=2)

# %%
df.sample(3)
# Out:
#          Brand   Model  Year Fuel Type  Kilometer   Price       City
# 2395   Hyundai   Xcent  2015    Petrol      26856  400000       Pune
# 5667    Toyota  Innova  2013    Diesel     133842  735000  Ahmedabad
# 2460  Mahindra  Quanto  2013    Diesel      88515  242000  Bangalore

# %%
sns.catplot("Fuel Type","Price",data=df)

# %%
sns.catplot("Price","Fuel Type",data=df)
