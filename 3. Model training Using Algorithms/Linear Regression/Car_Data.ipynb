# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import load_boston

# %%
data=pd.read_excel("car_data.xlsx",sheet_name='cars_bangalore')

# %%
data.sample()
# Out:
#            Brand  Model  Year Fuel Type  Kilometer   Price       City
# 6000  Volkswagen  Vento  2011    Diesel     148992  270000  Ahmedabad

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6077 entries, 0 to 6076
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Brand      6077 non-null   object
#  1   Model      6077 non-null   object
#  2   Year       6077 non-null   int64
#  3   Fuel Type  6077 non-null   object
#  4   Kilometer  6077 non-null   int64
#  5   Price      6077 non-null   int64
#  6   City       6077 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 332.5+ KB

# %%
sns.boxplot(data.corr())

# %%
sns.pairplot(data.corr())

# %%
sns.heatmap(data.corr(method ='pearson'),annot=True)

# %%
sns.heatmap(data.corr(method ='kendall'),annot=True)

# %%
sns.heatmap(data.corr(method ='spearman'),annot=True)

# %%
sns.relplot('Year','Price',data=data,hue="Fuel Type",kind='line')

# %%
data.sample()
# Out:
#      Brand Model  Year   Fuel Type  Kilometer  Price       City
# 866  Honda  City  2005  Petrol+CNG     120277  70000  New Delhi

# %%
data.columns
# Out:
# Index(['Brand', 'Model', 'Year', 'Fuel Type', 'Kilometer', 'Price', 'City'], dtype='object')

# %%
x=data['Year']

y=data['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-3930ea67a7b1> in <module>
# ----> 1 lm.fit(X_train,y_train)
#
# C:\Python\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# C:\Python\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# C:\Python\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# C:\Python\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     794         raise ValueError("y cannot be None")
#     795
# --> 796     X = check_array(X, accept_sparse=accept_sparse,
#     797                     accept_large_sparse=accept_large_sparse,
#     798                     dtype=dtype, order=order, copy=copy,
#
# C:\Python\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# C:\Python\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     618             # If input is 1D raise error
#     619             if array.ndim == 1:
# --> 620                 raise ValueError(
#     621                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     622                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[2011 2010 2005 ... 2005 2009 2004].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
print(lm.intercept_)

# %%
lm.coef_

# %%
pd.DataFrame(lm.coef_,X_train.columns,columns=['Coeff'])

# %%
predictions=lm.predict(X_test)

# %%
predictions

# %%
y_test

# %%
plt.scatter(predictions,y_test)

# %%
sns.distplot(y_test-predictions)
